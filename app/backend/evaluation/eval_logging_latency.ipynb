# %% [markdown]
# ## Logging latency evaluation (Postgres → Elasticsearch alerts-index)
#
# This notebook:
# - Connects to Postgres directly.
# - Runs test queries.
# - Records wall-clock timestamps around each query.
# - Polls Elasticsearch `alerts-index` and records the newest alert `@timestamp` observed after each query.
#
# **Configurations
# - Postgres: `localhost:15432`, db `thesisdb`, user `myuser`, password `mypassword`
# - Elasticsearch: `http://localhost:9200`

# %%
import time
import json
from datetime import datetime, timezone
from typing import Optional, Dict, Any, List

import psycopg2
import psycopg2.extras
import requests


def utc_now_iso() -> str:
    return datetime.now(timezone.utc).isoformat()


def parse_es_ts(ts: Optional[str]) -> Optional[datetime]:
    if not ts:
        return None
    # Elasticsearch usually returns Example: 2025-12-04T05:45:00.968013336Z
    s = ts
    if s.endswith('Z'):
        s = s[:-1] + '+00:00'

    if '.' in s:
        head, frac = s.split('.', 1)
        if '+' in frac:
            frac_digits, tz = frac.split('+', 1)
            frac_digits = frac_digits[:6]
            s = f"{head}.{frac_digits}+{tz}"
    return datetime.fromisoformat(s)


PG = {
    "host": "localhost",
    "port": 15432,
    "dbname": "thesisdb",
    "user": "myuser",
    "password": "mypassword",
}

ES = {
    "base_url": "http://localhost:9200",
    "alerts_index": "alerts-index",
}

print("Configured PG:", {k: v for k, v in PG.items() if k != "password"})
print("Configured ES:", ES)
# Out:
# Configured PG: {'host': 'localhost', 'port': 5432, 'dbname': 'thesisdb', 'user': 'myuser'}
# Configured ES: {'base_url': 'http://localhost:9200', 'alerts_index': 'alerts-index'}

# %%
def pg_connect():
    conn = psycopg2.connect(**PG)
    conn.autocommit = True
    return conn


def es_latest_alert_ts() -> Optional[str]:
    """Return newest alerts-index @timestamp (string) or None if empty/not found."""
    url = f"{ES['base_url'].rstrip('/')}/{ES['alerts_index']}/_search"
    body = {
        "size": 1,
        "sort": [{"@timestamp": "desc"}],
        "_source": ["@timestamp", "rule_id", "message", "alert_id"],
        "query": {"match_all": {}},
    }
    r = requests.get(url, json=body, timeout=10)
    if r.status_code == 404:
        return None
    r.raise_for_status()
    data = r.json()
    hits = data.get("hits", {}).get("hits", [])
    if not hits:
        return None
    return hits[0].get("_source", {}).get("@timestamp")


def es_wait_new_alert(after_ts: Optional[str], timeout_s: float = 600.0, poll_s: float = 1.0) -> Dict[str, Any]:
    """Poll until alerts-index newest @timestamp changes (or timeout)."""
    start = time.time()
    while True:
        cur = es_latest_alert_ts()
        if cur and cur != after_ts:
            return {"status": "updated", "newest_alert_ts": cur, "wait_s": round(time.time() - start, 3)}
        if time.time() - start > timeout_s:
            return {"status": "timeout", "newest_alert_ts": cur, "wait_s": round(time.time() - start, 3)}
        time.sleep(poll_s)

# %%
# Configure test queries here.

TEST_QUERIES: List[Dict[str, Any]] = [
    {
        "name": "select_row",
        "sql": "SET application_name = 'eval_logging'; SELECT count(*) FROM test1123_f;",
    },
    {
        "name": "insert_row",
        "sql": "SET application_name = 'eval_logging'; INSERT INTO test1123_f (row_number, \"Shipment_ID\", \"Origin_Warehouse\") VALUES (9999, 'TEST001', 'WAREHOUSE_A');",
    },
    {
        "name": "update_row",
        "sql": "SET application_name = 'eval_logging'; UPDATE test1123_f SET \"Origin_Warehouse\" = 'WAREHOUSE_B' WHERE row_number = 9999;",
    },
    {
       "name": "delete_row",
      "sql": "SET application_name = 'eval_logging'; DELETE FROM test1123_f WHERE row_number = 9999;",
    }
]

# Polling settings for alerts-index
ALERT_POLL_TIMEOUT_S = 600.0
ALERT_POLL_INTERVAL_S = 1.0

print("Loaded", len(TEST_QUERIES), "test queries")
# Out:
# Loaded 4 test queries

# %%
def run_eval(test_queries: List[Dict[str, Any]]) -> List[Dict[str, Any]]:
    results: List[Dict[str, Any]] = []

    baseline_alert_ts = es_latest_alert_ts()
    print("Baseline newest alert @timestamp:", baseline_alert_ts)

    with pg_connect() as conn:
        with conn.cursor(cursor_factory=psycopg2.extras.RealDictCursor) as cur:
            for q in test_queries:
                name = q["name"]
                sql = q["sql"]

                # Record pre-query alert timestamp (newest alert doc)
                pre_alert_ts = es_latest_alert_ts()

                # Run query and time it
                t_start_iso = utc_now_iso()
                t_start = time.time()
                try:
                    cur.execute(sql)
                    # Fetch all result sets if any (only last SELECT is fetchable)
                    row = None
                    if cur.description is not None:
                        row = cur.fetchone()
                except Exception as e:
                    row = None
                    err = repr(e)
                else:
                    err = None
                t_end = time.time()
                t_end_iso = utc_now_iso()

                # Wait for a new alert to appear
                wait_result = es_wait_new_alert(pre_alert_ts, timeout_s=ALERT_POLL_TIMEOUT_S, poll_s=ALERT_POLL_INTERVAL_S)

                results.append({
                    "name": name,
                    "sql": sql,
                    "query_start_utc": t_start_iso,
                    "query_end_utc": t_end_iso,
                    "query_duration_s": round(t_end - t_start, 6),
                    "pg_result_first_row": row,
                    "error": err,
                    "alerts_newest_ts_before": pre_alert_ts,
                    **wait_result,
                })

                print(f"[{name}] duration={results[-1]['query_duration_s']}s alert_status={wait_result['status']} wait={wait_result['wait_s']}s")

    return results


eval_results = run_eval(TEST_QUERIES)
print("Done. Rows:", len(eval_results))
# Out:
# Baseline newest alert @timestamp: 2025-12-20T06:15:40.306Z
# [select_count] duration=0.126715s alert_status=timeout wait=600.705s
# [insert_row] duration=0.061575s alert_status=timeout wait=600.108s
# [update_row] duration=0.011962s alert_status=timeout wait=600.734s
# [delete_row] duration=0.009665s alert_status=timeout wait=600.967s
# Done. Rows: 4

# %%
import os
import pandas as pd


out_path = "./logging_latency_eval.csv"
new_df = pd.DataFrame(eval_results)

if os.path.exists(out_path) and os.path.getsize(out_path) > 0:
    old_df = pd.read_csv(out_path)
    combined = pd.concat([old_df, new_df], ignore_index=True)
else:
    combined = new_df

combined.to_csv(out_path, index=False)

print(f"Wrote {out_path} (rows now: {len(combined)})")
# Out:
# Wrote ./logging_latency_eval.csv (rows now: 23)

# %%
csv = pd.read_csv(out_path)

# %%
csv
# Out:
#             name                                                sql  \
# 0   select_count  SET application_name = 'eval_logging'; SELECT ...
# 1   select_count  SET application_name = 'eval_logging'; SELECT ...
# 2   select_count  SET application_name = 'eval_logging'; SELECT ...
# 3   select_count  SET application_name = 'eval_logging'; SELECT ...
# 4   select_count  SET application_name = 'eval_logging'; SELECT ...
# 5   select_count  SET application_name = 'eval_logging'; SELECT ...
# 6   select_count  SET application_name = 'eval_logging'; SELECT ...
# 7   select_count  SET application_name = 'eval_logging'; SELECT ...
# 8   select_count  SET application_name = 'eval_logging'; SELECT ...
# 9   select_count  SET application_name = 'eval_logging'; SELECT ...
# 10    delete_row  SET application_name = 'eval_logging'; DELETE ...
# 11    insert_row  SET application_name = 'eval_logging'; INSERT ...
# 12    update_row  SET application_name = 'eval_logging'; UPDATE ...
# 13    delete_row  SET application_name = 'eval_logging'; DELETE ...
# 14    insert_row  SET application_name = 'eval_logging'; INSERT ...
# 15    update_row  SET application_name = 'eval_logging'; UPDATE ...
# 16    delete_row  SET application_name = 'eval_logging'; DELETE ...
# 17    insert_row  SET application_name = 'eval_logging'; INSERT ...
# 18    update_row  SET application_name = 'eval_logging'; UPDATE ...
#
#                      query_start_utc                     query_end_utc  \
# 0   2025-12-18T03:29:25.821124+00:00  2025-12-18T03:29:25.842123+00:00
# 1   2025-12-18T03:36:20.111979+00:00  2025-12-18T03:36:20.125813+00:00
# 2   2025-12-18T03:42:25.177831+00:00  2025-12-18T03:42:25.192965+00:00
# 3   2025-12-18T03:48:10.109009+00:00  2025-12-18T03:48:10.159437+00:00
# 4   2025-12-18T03:53:22.792045+00:00  2025-12-18T03:53:22.816820+00:00
# 5   2025-12-18T03:59:21.513030+00:00  2025-12-18T03:59:21.640041+00:00
# 6   2025-12-18T04:06:15.540392+00:00  2025-12-18T04:06:15.569676+00:00
# 7   2025-12-18T04:11:24.116871+00:00  2025-12-18T04:11:24.141354+00:00
# 8   2025-12-18T04:17:09.608202+00:00  2025-12-18T04:17:09.673958+00:00
# 9   2025-12-18T04:23:04.450528+00:00  2025-12-18T04:23:04.500748+00:00
# 10  2025-12-18T05:12:32.398103+00:00  2025-12-18T05:12:32.414441+00:00
# 11  2025-12-18T05:28:55.658382+00:00  2025-12-18T05:28:55.681786+00:00
# 12  2025-12-18T05:51:28.366156+00:00  2025-12-18T05:51:28.903473+00:00
# 13  2025-12-19T05:17:15.378768+00:00  2025-12-19T05:17:15.401117+00:00
# 14  2025-12-19T05:48:26.811675+00:00  2025-12-19T05:48:26.832997+00:00
# 15  2025-12-19T06:02:40.838275+00:00  2025-12-19T06:02:40.905035+00:00
# 16  2025-12-20T05:23:46.996174+00:00  2025-12-20T05:23:47.020846+00:00
# 17  2025-12-20T05:52:37.706070+00:00  2025-12-20T05:52:37.727246+00:00
# 18  2025-12-20T06:08:44.527034+00:00  2025-12-20T06:08:44.643620+00:00
#
#     query_duration_s              pg_result_first_row  \
# 0           0.020969      RealDictRow([('count', 1)])
# 1           0.013808      RealDictRow([('count', 1)])
# 2           0.015120      RealDictRow([('count', 1)])
# 3           0.050395  RealDictRow([('count', 12999)])
# 4           0.024743  RealDictRow([('count', 12999)])
# 5           0.126960  RealDictRow([('count', 12999)])
# 6           0.029253  RealDictRow([('count', 12999)])
# 7           0.024450  RealDictRow([('count', 12999)])
# 8           0.065739  RealDictRow([('count', 12999)])
# 9           0.050193  RealDictRow([('count', 12999)])
# 10          0.016325                              NaN
# 11          0.023374                              NaN
# 12          0.536929                              NaN
# 13          0.022318                              NaN
# 14          0.021295                              NaN
# 15          0.066733                              NaN
# 16          0.024651                              NaN
# 17          0.021152                              NaN
# 18          0.116570                              NaN
#
#                                                 error  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  UniqueViolation('duplicate key value violates ...
# 12                                                NaN
# 13                                                NaN
# 14  UniqueViolation('duplicate key value violates ...
# 15                                                NaN
# 16                                                NaN
# 17  UniqueViolation('duplicate key value violates ...
# 18                                                NaN
#
#      alerts_newest_ts_before   status           newest_alert_ts   wait_s
# 0   2025-12-18T03:23:58.226Z  updated  2025-12-18T03:30:16.350Z   54.639
# 1   2025-12-18T03:30:16.350Z  updated  2025-12-18T03:36:24.343Z    7.285
# 2   2025-12-18T03:36:24.343Z  updated  2025-12-18T03:42:39.768Z   17.596
# 3   2025-12-18T03:42:39.768Z  updated  2025-12-18T03:48:57.729Z   51.546
# 4   2025-12-18T03:48:57.729Z  updated  2025-12-18T03:54:12.887Z   53.547
# 5   2025-12-18T03:54:12.887Z  updated  2025-12-18T03:59:41.333Z   23.791
# 6   2025-12-18T03:59:41.333Z  updated  2025-12-18T04:06:42.371Z   30.857
# 7   2025-12-18T04:06:42.371Z  updated  2025-12-18T04:11:57.464Z   37.182
# 8   2025-12-18T04:11:57.464Z  updated  2025-12-18T04:18:08.206Z   61.870
# 9   2025-12-18T04:18:08.206Z  updated  2025-12-18T04:23:17.611Z   16.446
# 10  2025-12-18T04:45:09.713Z  updated  2025-12-18T05:15:24.659Z  176.062
# 11  2025-12-18T05:15:24.659Z  updated  2025-12-18T05:30:58.011Z  128.986
# 12  2025-12-18T05:30:58.011Z  updated  2025-12-18T05:55:59.546Z  273.607
# 13  2025-12-18T06:00:21.983Z  updated  2025-12-19T05:20:56.157Z  223.288
# 14  2025-12-19T05:20:56.157Z  updated  2025-12-19T05:50:12.203Z  108.167
# 15  2025-12-19T05:50:12.203Z  updated  2025-12-19T06:05:57.095Z  199.450
# 16  2025-12-20T04:50:11.084Z  updated  2025-12-20T05:25:27.005Z  102.934
# 17  2025-12-20T05:25:27.005Z  updated  2025-12-20T05:55:53.632Z  199.145
# 18  2025-12-20T05:55:53.632Z  updated  2025-12-20T06:10:30.659Z  109.575

# %%
df_grouped_stats = csv.groupby('name')['wait_s'].agg(['mean', 'count'])

# %%
df_grouped_stats
# Out:
#                     mean  count
# name
# delete_row    167.428000      3
# insert_row    145.432667      3
# select_count   35.475900     10
# update_row    194.210667      3
