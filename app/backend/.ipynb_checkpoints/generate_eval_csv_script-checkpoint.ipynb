# %%
from main import *
from fastapi.testclient import TestClient

# %%
client = TestClient(app)

eval_data_path = '/Users/jingtingdai/Desktop/Master_Thesis/learning/test/data/eval_dataset/'
for file in os.listdir(eval_data_path):
    print(file)
    cur_file = os.path.join(eval_data_path, file)
    print(cur_file)
    response = client.post('/upload-csv/', files={'file':open(cur_file,'rb')})
    response = client.get('real-data')
    client.get('delete-table')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1415, in Connection.execute(self, statement, parameters, execution_options)
#    1414 try:
# -> 1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
#
# AttributeError: 'str' object has no attribute '_execute_on_connection'
#
# The above exception was the direct cause of the following exception:
#
# ObjectNotExecutableError                  Traceback (most recent call last)
# Cell In[12], line 8
#       6 query = f'ALTER TABLE {table_name};'
#       7 connection = engine.connect()
# ----> 8 connection.execute(query)
#       9 i+=1
#      10 print(file)
#
# File /opt/miniconda3/lib/python3.9/site-packages/sqlalchemy/engine/base.py:1417, in Connection.execute(self, statement, parameters, execution_options)
#    1415     meth = statement._execute_on_connection
#    1416 except AttributeError as err:
# -> 1417     raise exc.ObjectNotExecutableError(statement) from err
#    1418 else:
#    1419     return meth(
#    1420         self,
#    1421         distilled_parameters,
#    1422         execution_options or NO_OPTIONS,
#    1423     )
#
# ObjectNotExecutableError: Not an executable object: 'ALTER TABLE eval_10_1;'
